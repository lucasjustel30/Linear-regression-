# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasjustel30/Linear-regression-py/blob/main/RegLinear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt  
import pandas as pd  
from sklearn.linear_model import LinearRegression

data = pd.read_csv('dados.txt')
X = data.iloc[:, 0].values.reshape(-1, 1) 
Y = data.iloc[:, 1].values.reshape(-1, 1) 
linear_regressor = LinearRegression()  
linear_regressor.fit(X, Y)  
Y_pred = linear_regressor.predict(X)  

plt.xlabel('SI', size = '16')
plt.ylabel('Dias de internação', size='16')

plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.show()
